# %% [markdown]
# <a href="https://colab.research.google.com/github/saneshj/Python11/blob/main/python_ucch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url=("https://raw.githubusercontent.com/saneshj/Python11/main/Descriptipn_20220803.csv")
data1 = pd.read_csv(url)
data1
# Out:
#         DEVICE NAME               DESCRIPTION  Directory Number 1  \
# 0   SEPB000B4D85C94  DU_Acquisition_Telesales                2682
# 1   SEP00D6FE05A3EC  DU_Acquisition_Telesales                2684
# 2   SEP00AF1F9DC714  DU_Acquisition_Telesales                2368
# 3   SEPF09E630F3A7A  DU_Acquisition_Telesales                2685
# 4   SEP64E9502EE235  DU_Acquisition_Telesales                2686
# ..              ...                       ...                 ...
# 76      SEPLTIB20M6  DU_Acquisition_Telesales                2627
# 77      SEPLTHP5HS9  DU_Acquisition_Telesales                2413
# 78      SEPLTIBBH68  DU_Acquisition_Telesales                2438
# 79      SEPLTIB9HMH  DU_Acquisition_Telesales                2490
# 80      SEPLTIBZK3T  DU_Acquisition_Telesales                2414
#
#     DIRECTORY NUMBER 1  AAR DESTINATION MASK 1  ASCII DISPLAY 1  \
# 0                 2682                 3699155             2682
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   DEVICE NAME                   81 non-null     object
#  1   DESCRIPTION                   81 non-null     object
#  2   Directory Number 1            81 non-null     int64
#  3   DIRECTORY NUMBER 1            81 non-null     int64
#  4   AAR DESTINATION MASK 1        81 non-null     int64
#  5   ASCII DISPLAY 1               81 non-null     int64
#  6   ALERTING NAME 1               81 non-null     int64
#  7   AUTO ANSWER 1                 81 non-null     object
#  8   EXTERNAL PHONE NUMBER MASK 1  81 non-null     int64
#  9   DISPLAY 1                     81 non-null     int64
# dtypes: int64(7), object(3)
# memory usage: 6.5+ KB

# %%
data1['DEVICE NAME']
# Out:
# 0     SEPB000B4D85C94
# 1     SEP00D6FE05A3EC
# 2     SEP00AF1F9DC714
# 3     SEPF09E630F3A7A
# 4     SEP64E9502EE235
#            ...
# 76        SEPLTIB20M6
# 77        SEPLTHP5HS9
# 78        SEPLTIBBH68
# 79        SEPLTIB9HMH
# 80        SEPLTIBZK3T
# Name: DEVICE NAME, Length: 81, dtype: object

# %%
data1['EXTERNAL PHONE NUMBER MASK 1'].value_counts().plot(kind='pie')

# %%
url="https://raw.githubusercontent.com/saneshj/Python11/main/Agent.xlsx"
df = pd.read_excel(url)
df
# Out:
#        SkillTargetID  PersonID  AgentDeskSettingsID  ScheduleID  PeripheralID  \
# 0               5039      5001               5002.0         NaN          5000
# 1               5040      5002               5002.0         NaN          5000
# 2               5041      5003               5002.0         NaN          5000
# 3               5042      5004               5002.0         NaN          5000
# 4               5148      5078               5007.0         NaN          5000
# ...              ...       ...                  ...         ...           ...
# 10866          32614     29548               5007.0         NaN          5000
# 10867          32615     29549               5007.0         NaN          5000
# 10868          32616     29550               5007.0         NaN          5000
# 10869          32617     29551               5007.0         NaN          5000
# 10870          32618     29552               5007.0         NaN          5000
#
# ...
