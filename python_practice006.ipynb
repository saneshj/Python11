# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url ="https://raw.githubusercontent.com/saneshj/Python11/main/DS11/Datasets-master/movie_dataset.csv"
dataset1 = pd.read_csv(url)
dataset1.head()
# Out:
#    index     budget                                    genres  \
# 0      0  237000000  Action Adventure Fantasy Science Fiction
# 1      1  300000000                  Adventure Fantasy Action
# 2      2  245000000                    Action Adventure Crime
# 3      3  250000000               Action Crime Drama Thriller
# 4      4  260000000          Action Adventure Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  culture clash future space war space colony so...                en
# 1  ocean drug abuse exotic island east india trad...                en
# ...

# %%
dataset1.shape
# Out:
# (4803, 24)

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 4803 non-null   int64
#  1   budget                4803 non-null   int64
#  2   genres                4775 non-null   object
#  3   homepage              1712 non-null   object
#  4   id                    4803 non-null   int64
#  5   keywords              4391 non-null   object
#  6   original_language     4803 non-null   object
#  7   original_title        4803 non-null   object
#  8   overview              4800 non-null   object
#  9   popularity            4803 non-null   float64
#  10  production_companies  4803 non-null   object
#  11  production_countries  4803 non-null   object
#  12  release_date          4802 non-null   object
#  13  revenue               4803 non-null   int64
#  14  runtime               4801 non-null   float64
# ...

# %%
dataset1.describe()
# Out:
#              index        budget             id   popularity       revenue  \
# count  4803.000000  4.803000e+03    4803.000000  4803.000000  4.803000e+03
# mean   2401.000000  2.904504e+07   57165.484281    21.492301  8.226064e+07
# std    1386.651002  4.072239e+07   88694.614033    31.816650  1.628571e+08
# min       0.000000  0.000000e+00       5.000000     0.000000  0.000000e+00
# 25%    1200.500000  7.900000e+05    9014.500000     4.668070  0.000000e+00
# 50%    2401.000000  1.500000e+07   14629.000000    12.921594  1.917000e+07
# 75%    3601.500000  4.000000e+07   58610.500000    28.313505  9.291719e+07
# max    4802.000000  3.800000e+08  459488.000000   875.581305  2.787965e+09
#
#            runtime  vote_average    vote_count
# count  4801.000000   4803.000000   4803.000000
# mean    106.875859      6.092172    690.217989
# std      22.611935      1.194612   1234.585891
# min       0.000000      0.000000      0.000000
# 25%      94.000000      5.600000     54.000000
# ...

# %%
dataset1['genres'].value_counts().plot(kind='pie')

# %%
dataset1['genres'].value_counts()
# Out:
# Drama                                     370
# Comedy                                    282
# Drama Romance                             164
# Comedy Romance                            144
# Comedy Drama                              142
#                                          ...
# Adventure Comedy Crime Science Fiction      1
# Action Comedy Family Adventure              1
# Drama Adventure Western                     1
# Adventure Fantasy Action Romance            1
# Comedy Drama Romance TV Movie               1
# Name: genres, Length: 1168, dtype: int64

# %%
dataset1.sort_values('vote_count').tail(10)
# Out:
#      index     budget                                             genres  \
# 127    127  150000000          Action Adventure Science Fiction Thriller
# 426    426   75000000                  Science Fiction Adventure Fantasy
# 94      94  170000000                   Action Science Fiction Adventure
# 287    287  100000000                                      Drama Western
# 95      95  165000000                    Adventure Drama Science Fiction
# 788    788   58000000                            Action Adventure Comedy
# 16      16  220000000                   Science Fiction Action Adventure
# 0        0  237000000           Action Adventure Fantasy Science Fiction
# 65      65  185000000                        Drama Action Crime Thriller
# 96      96  160000000  Action Thriller Science Fiction Mystery Adventure
#
#                                          homepage      id  \
# 127                   http://www.madmaxmovie.com/   76341
# ...

# %%
ds2=dataset1.sort_values('vote_count').tail(12)
ds2.shape
# Out:
# (12, 24)

# %%
ds2['vote_count'].plot(kind='pie',radius=3, labels=ds2.original_title)

# %%
ds3=ds2[["original_title","vote_count"]]
ds3
# Out:
#               original_title  vote_count
# 3      The Dark Knight Rises        9106
# 662               Fight Club        9413
# 127       Mad Max: Fury Road        9427
# 426         The Hunger Games        9455
# 94   Guardians of the Galaxy        9742
# 287         Django Unchained       10099
# 95              Interstellar       10867
# 788                 Deadpool       10995
# 16              The Avengers       11776
# 0                     Avatar       11800
# 65           The Dark Knight       12002
# 96                 Inception       13752

# %%
ds4=dataset1[["original_title","budget"]]
ds4
# Out:
#                                 original_title     budget
# 0                                       Avatar  237000000
# 1     Pirates of the Caribbean: At World's End  300000000
# 2                                      Spectre  245000000
# 3                        The Dark Knight Rises  250000000
# 4                                  John Carter  260000000
# ...                                        ...        ...
# 4798                               El Mariachi     220000
# 4799                                 Newlyweds       9000
# 4800                 Signed, Sealed, Delivered          0
# 4801                          Shanghai Calling          0
# 4802                         My Date with Drew          0
#
# [4803 rows x 2 columns]

# %%
ds5=ds4.sort_values('budget').tail(20)
ds5
# Out:
#                                  original_title     budget
# 14                                 Man of Steel  225000000
# 18                               Men in Black 3  225000000
# 0                                        Avatar  237000000
# 2                                       Spectre  245000000
# 9            Batman v Superman: Dawn of Justice  250000000
# 8        Harry Potter and the Half-Blood Prince  250000000
# 26                   Captain America: Civil War  250000000
# 98            The Hobbit: An Unexpected Journey  250000000
# 19    The Hobbit: The Battle of the Five Armies  250000000
# 22          The Hobbit: The Desolation of Smaug  250000000
# 46                   X-Men: Days of Future Past  250000000
# 3                         The Dark Knight Rises  250000000
# 13                              The Lone Ranger  255000000
# 5                                  Spider-Man 3  258000000
# 6                                       Tangled  260000000
# ...

# %%
ds5['budget'].plot(kind='bar', figsize=(40,10),xlabel=ds5.original_title)

# %%
ds6=ds2[["original_title","vote_count","popularity", "vote_average"]]
ds6
# Out:
#               original_title  vote_count  popularity  vote_average
# 3      The Dark Knight Rises        9106  112.312950           7.6
# 662               Fight Club        9413  146.757391           8.3
# 127       Mad Max: Fury Road        9427  434.278564           7.2
# 426         The Hunger Games        9455   68.550698           6.9
# 94   Guardians of the Galaxy        9742  481.098624           7.9
# 287         Django Unchained       10099   82.121691           7.8
# 95              Interstellar       10867  724.247784           8.1
# 788                 Deadpool       10995  514.569956           7.4
# 16              The Avengers       11776  144.448633           7.4
# 0                     Avatar       11800  150.437577           7.2
# 65           The Dark Knight       12002  187.322927           8.2
# 96                 Inception       13752  167.583710           8.1

# %%
ds6.plot(kind='bar', stacked=True, figsize=(20,20),xlabel=ds5.original_title)

# %%
ds6=dataset1[["original_title","original_language"]]
ds6.shape
ds6.info
# Out:
# <bound method DataFrame.info of                                 original_title original_language
# 0                                       Avatar                en
# 1     Pirates of the Caribbean: At World's End                en
# 2                                      Spectre                en
# 3                        The Dark Knight Rises                en
# 4                                  John Carter                en
# ...                                        ...               ...
# 4798                               El Mariachi                es
# 4799                                 Newlyweds                en
# 4800                 Signed, Sealed, Delivered                en
# 4801                          Shanghai Calling                en
# 4802                         My Date with Drew                en
#
# [4803 rows x 2 columns]>

# %%
ds2['original_language'].value_counts().plot(kind='pie',radius=3)

# %%
ds2['original_language'].value_counts()
# Out:
# en    12
# Name: original_language, dtype: int64

# %%
ds7=dataset1[["original_title","homepage"]]
ds7
# Out:
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                homepage
# 0                           http://www.avatarmovie.com/
# 1          http://disney.go.com/disneypictures/pirates/
# 2           http://www.sonypictures.com/movies/spectre/
# 3                    http://www.thedarkknightrises.com/
# 4                  http://movies.disney.com/john-carter
# ...                                                 ...
# ...

# %%
ds8=dataset1[["original_title","keywords"]]
ds8
# Out:
#                                 original_title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4798                               El Mariachi
# 4799                                 Newlyweds
# 4800                 Signed, Sealed, Delivered
# 4801                          Shanghai Calling
# 4802                         My Date with Drew
#
#                                                keywords
# 0     culture clash future space war space colony so...
# 1     ocean drug abuse exotic island east india trad...
# 2            spy based on novel secret agent sequel mi6
# 3     dc comics crime fighter terrorist secret ident...
# 4     based on novel mars medallion space travel pri...
# ...                                                 ...
# ...

# %%
ds8['keywords'].value_counts()
# Out:
# independent film                                             55
# woman director                                               42
# duringcreditsstinger                                         15
# sport                                                        13
# independent film woman director                              10
#                                                              ..
# broken neck fbi agent wall safe trashed house aerial shot     1
# superhero kids and family                                     1
# 1970s skyscraper based on true story tightrope planning       1
# american football mythology chinese food kangaroo             1
# obsession camcorder crush dream girl                          1
# Name: keywords, Length: 4219, dtype: int64
